# %%
import numpy as np
from scipy import stats
rng = np.random.default_rng()
sample1 = stats.uniform.rvs(size=100, random_state=rng)
sample2 = stats.norm.rvs(size=110, random_state=rng)
response = stats.ks_2samp(sample1, sample2)

# %%
sample1
# Out:
# array([0.3733692 , 0.91152316, 0.84001151, 0.16189681, 0.64149357,
#        0.59998706, 0.19796761, 0.87856852, 0.12296445, 0.77247442,
#        0.03933911, 0.6728811 , 0.3701984 , 0.85555456, 0.0097875 ,
#        0.44733365, 0.92291977, 0.11065636, 0.63045442, 0.79473862,
#        0.66386394, 0.06733994, 0.32660041, 0.68057571, 0.51010007,
#        0.84978787, 0.85379691, 0.41188169, 0.05043955, 0.74953064,
#        0.02029114, 0.42857958, 0.34932911, 0.39610283, 0.58764418,
#        0.06606383, 0.71798076, 0.33880708, 0.07518374, 0.39179043,
#        0.49384908, 0.44833383, 0.65896748, 0.13962862, 0.8924536 ,
#        0.47015862, 0.72192595, 0.19776473, 0.9340701 , 0.56453666,
#        0.64598815, 0.59546718, 0.11156821, 0.41376049, 0.66770903,
#        0.09090666, 0.87802421, 0.0716846 , 0.66684481, 0.10940251,
#        0.96882683, 0.93958361, 0.94754681, 0.18971394, 0.73991522,
#        0.84073883, 0.65938088, 0.92662288, 0.27559402, 0.52475086,
# ...

# %%
sample2
# Out:
# array([ 0.52318258, -0.88423647, -0.68265342, -0.24970028,  0.62613871,
#         1.76353794, -0.24901255, -0.67105119,  0.11352129, -0.37976443,
#        -0.7784635 ,  0.06100816, -0.11374185,  0.5041586 ,  0.09507193,
#         0.05409602, -1.20612936, -0.68283356, -0.80104163, -1.06728014,
#         0.63094453,  0.61433002,  0.83184744, -1.05832217, -0.84845935,
#         0.11574354,  0.04631015,  1.20968767, -0.55113   , -0.33658139,
#         0.16914491, -0.45979119,  0.0153311 , -1.27389597,  1.10459112,
#         0.89908964, -1.19266029,  0.39566189, -1.56981382,  2.78579256,
#         1.20797633,  0.25169682, -0.38153025,  0.21785778,  0.88650371,
#        -0.48788655, -2.0850467 ,  1.03813721, -0.9794774 ,  0.60929486,
#         0.91778953, -0.73978971, -0.59448863, -0.61750965, -1.81197775,
#         0.45036211,  1.4691276 , -0.70093566,  0.26162966,  0.35411982,
#        -1.48431949,  0.29989215,  1.81733304, -1.58518266,  0.79081435,
# ...

# %%
response
# Out:
# KstestResult(statistic=0.5272727272727272, pvalue=7.26220122467953e-14)

# %%
round(response.pvalue,16)
# Out:
# 7.26e-14

# %%
#Anomly in my dataset

1.High Null Value
2. Missing COlumns
3. Outlier
4. Categorical: 
Gender--> MALE, FEMALE,OTHER

# %%
import pandas as pd

# %%
l1=[1,2,3,4]
l2=[4,5,6,7]

for l1_val,l2_val in zip(l1,l2):
    print(l1_val,l2_val)
# Out:
# 1 4
# 2 5
# 3 6
# 4 7

# %%
df = pd.read_csv('/config/workspace/artifact/12202022__215318/data_ingestion/dataset/train.csv')

# %%
drop_col_names =[]
for col_name,miss_per in zip((df.isnull().sum()/df.shape[0]).index,(df.isnull().sum()/df.shape[0]).values):
    print(col_name, miss_per*100)
    if miss_per>0.3:
        drop_col_names.append(col_name)
# Out:
# class 0.0
# aa_000 0.0
# ab_000 77.02590673575129
# ac_000 5.848013816925734
# ad_000 25.39550949913644
# ae_000 4.352331606217617
# af_000 4.352331606217617
# ag_000 1.060449050086356
# ag_001 1.060449050086356
# ag_002 1.060449050086356
# ag_003 1.060449050086356
# ag_004 1.060449050086356
# ag_005 1.060449050086356
# ag_006 1.060449050086356
# ag_007 1.060449050086356
# ag_008 1.060449050086356
# ag_009 1.060449050086356
# ah_000 1.0535405872193437
# ai_000 1.0500863557858378
# aj_000 1.0500863557858378
# ak_000 7.644214162348878
# al_000 1.0535405872193437
# am_0 1.0500863557858378
# an_000 1.0535405872193437
# ao_000 0.9844559585492229
# ap_000 1.0535405872193437
# aq_000 0.9844559585492229
# ar_000 4.7426597582038
# as_000 1.0500863557858378
# at_000 1.0500863557858378
# au_000 1.0500863557858378
# av_000 4.355785837651123
# ax_000 4.3592400690846285
# ay_000 1.060449050086356
# ay_001 1.060449050086356
# ay_002 1.060449050086356
# ay_003 1.060449050086356
# ...

# %%
drop_col_names
# Out:
# ['ab_000',
#  'bk_000',
#  'bl_000',
#  'bm_000',
#  'bn_000',
#  'bo_000',
#  'bp_000',
#  'bq_000',
#  'br_000',
#  'cr_000']
